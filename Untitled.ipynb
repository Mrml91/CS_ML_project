# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import h5py
import os

from kaggle_submit import submit_to_kaggle
from helpers import *

PICTURES_FOLDER = "pictures"
os.makedirs(PICTURES_FOLDER, exist_ok=True)

SLEEP_STAGES_COLORS = {
    0: "blue",
    1: "green",     
    2: "red",
    3: "black",
    4: "orange",
}

# %%
train_file = "kaggle_data/X_train.h5/X_train.h5"
test_file = "kaggle_data/X_test.h5/X_test.h5"

h5_train = h5py.File(train_file, mode='a')
h5_test = h5py.File(test_file, mode='a')

y_train = pd.read_csv("kaggle_data/y_train.csv", index_col=0, squeeze=True)

# %%
h5_train["pulse_max_logE"][1:10]
# Out:
# array([[33.51765 ],
#        [33.572014],
#        [33.384373],
#        [33.558205],
#        [33.608074],
#        [33.3813  ],
#        [33.57779 ],
#        [33.48447 ],
#        [33.494293]], dtype=float32)

# %%
from time_features import _create_time_features

_create_time_features(h5_train, overwrite=True)
_create_time_features(h5_test, overwrite=True)

# %%
plt.plot(h5_test["sleep_left"][:])
